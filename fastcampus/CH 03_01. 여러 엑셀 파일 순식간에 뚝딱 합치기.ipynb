# %% [markdown]
# ## 엑셀 데이터 병합하기

# %% [markdown]
# - 그런데 여기서 한 가지 큰 문제가 발생합니다.
#
#
# - 모든 OS가 같은 문제가 발생하는데, 일단 chrome에서 자동 다운로드를 진행하면 크롬 기본 지정경로인 "다운로드" 폴더에 엑셀파일이 저장됩니다.
#
#
# - 모두 다 같은 이름으로 저장이 되다보니, 번호만 쭉 붙어서 저장이 되는데 이러면 어느 지역파일인지 이름으로 알 수가 없습니다.
#
#
# - 그래서 pandas를 이용하여 특정 "시/도"의 크롤링이 끝날때마다 다운로드 폴더에 있는 다운로드된 엑셀파일(.xls)를 불러와서, 이름을 변경합니다.
#
#
# - 이름이 변경되면 일단 다른 "시/도"에서 다시 크롤링이 시작되었을 때 기존의 엑셀파일들과 이름이 중복되지 않기 때문에 "시/도"별 구분이 가능합니다.
#
#
# - 그 때마다 변경된 이름을 가진 엑셀파일들을 모아서 하나로 저장하면, "시/도" 별로 그때그때 취합한 데이터를 저장할 수 있습니다.
#
#
# - 엑셀을 불러오는 파트는 Pandas로 구현하였고, pandas를 통해서 데이터를 합쳐봅니다.

# %% [markdown]
# ### 서울시 데이터를 기준으로 테스트 해보기

# %% [markdown]
# - OS마다 다른 이름으로 엑셀 파일들이 지역구의 개수만큼 저장되어 있습니다. (다운로드 폴더에)
#
#
# - 다운로드 폴더에서 모든 .xls 파일을 가져옵니다. (주의 : 혹시 다운로드 폴더에 이전에 받았던 다른 xls 파일이 없는지 먼저 확인해봅니다.)
#
#
# - 다운로드 받는(받을) 모든 엑셀파일은 이름이 같습니다. 그렇기 때문에 시/도 마다 정리하기 위해서는 시/도 마다 엑셀파일들을 정리해서 규합해야합니다.
#
#
# - 파일이름은 혼동을 피하기 위해서 해당 시/도 이름을 파일에 넣습니다. (여기서는 "변환대상(시/도).xls"로 하겠습니다.)
#
#
# - glob 라이브러리를 통해서 파일이름들을 불러오고, os.rename 함수를 통해 파일이름을 변경합니다.
#
#
# - pandas의 read_excel 함수를 통해 모든 엑셀파일들을 불러와서 하나로 합칩니다.

# %%
# !pip install xlrd
# !pip install tqdm
# !pip install openpyxl
# !pip install ipywidgets widgetsnbextension pandas-profiling
# Out:
# Requirement already satisfied: ipywidgets in c:\users\chase\pylab\fastcampus\lib\site-packages (8.1.3)
# Requirement already satisfied: widgetsnbextension in c:\users\chase\pylab\fastcampus\lib\site-packages (4.0.11)
# Requirement already satisfied: pandas-profiling in c:\users\chase\pylab\fastcampus\lib\site-packages (3.2.0)
# Requirement already satisfied: comm>=0.1.3 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipywidgets) (3.0.11)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (1.14.0)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (3.9.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (2.8.2)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (6.0.1)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (3.1.4)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (2.1.5)
# Requirement already satisfied: visions==0.7.4 in c:\users\chase\pylab\fastcampus\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (2.0.1)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (0.12.4)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (2.32.3)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (4.66.4)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas-profiling) (1.12)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (23.2.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\chase\pylab\fastcampus\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.3)
# Requirement already satisfied: imagehash in c:\users\chase\pylab\fastcampus\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\chase\pylab\fastcampus\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.4.0)
# Requirement already satisfied: decorator in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: colorama in c:\users\chase\pylab\fastcampus\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\chase\pylab\fastcampus\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\chase\pylab\fastcampus\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\chase\pylab\fastcampus\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\chase\pylab\fastcampus\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chase\pylab\fastcampus\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2024.7.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\chase\pylab\fastcampus\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\chase\pylab\fastcampus\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\chase\pylab\fastcampus\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\chase\pylab\fastcampus\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.6.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\chase\pylab\fastcampus\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\chase\pylab\fastcampus\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
from glob import glob

stations_files = glob('./data/*.xls')
temp = pd.read_excel(stations_files[0], header=2)
temp2 = pd.read_excel(stations_files[1], header=2)
pd.concat([temp, temp2])
# Out:
#        지역                    상호                            주소        상표  \
# 0   서울특별시  재건에너지 재정제2주유소 고속셀프지점  서울특별시 강동구  천호대로 1246 (둔촌제2동)  HD현대오일뱅크
# 1   서울특별시               방아다리주유소          서울 강동구 동남로 811 (명일동)     SK에너지
# 2   서울특별시                구천면주유소         서울 강동구 구천면로 357 (암사동)  HD현대오일뱅크
# 3   서울특별시        (주)삼표에너지 고덕주유소           서울 강동구 고덕로 39 (암사동)     GS칼텍스
# 4   서울특별시          대성석유(주)길동주유소              서울 강동구 천호대로 1168     GS칼텍스
# 5   서울특별시           (주)소모 신월주유소        서울 강동구 양재대로 1323 (성내동)     GS칼텍스
# 6   서울특별시       (주)퍼스트오일 코알라주유소     서울특별시 강동구  올림픽로 556 (성내동)     S-OIL
# 7   서울특별시      주)지유에너지직영 오렌지주유소          서울 강동구 성안로 102 (성내동)     SK에너지
# 8   서울특별시           (주)소모 성내주유소         서울 강동구 올림픽로 578 (성내동)     GS칼텍스
# 9   서울특별시              sk해뜨는주유소         서울 강동구  상일로 132 (강일동)     SK에너지
# 10  서울특별시               천호현대주유소           서울 강동구 천중로 67 (천호동)  HD현대오일뱅크
# 11  서울특별시        지에스칼텍스㈜ 동서울주유소        서울 강동구 천호대로 1456 (상일동)     GS칼텍스
# 12  서울특별시                 광성주유소         서울 강동구 올림픽로 673 (천호동)     S-OIL
# 0   서울특별시        (주)자연에너지 국민주유소       서울 동대문구 답십리로 223 (답십리동)  HD현대오일뱅크
# 1   서울특별시              동서울고속주유소               서울 동대문구 한천로 414     SK에너지
# 2   서울특별시                 풍한주유소               서울 동대문구 안암로 168     SK에너지
# 3   서울특별시               재정제2주유소         서울 동대문구 사가정로 90 (전농동)  HD현대오일뱅크
# 4   서울특별시        (주)정건에너지 배봉로지점            서울 동대문구 서울시립대로 108  HD현대오일뱅크
# 5   서울특별시                 재정주유소         서울 동대문구 전농로 121 (전농동)  HD현대오일뱅크
# 6   서울특별시         대성산업(주)동마장주유소        서울 동대문구 고산자로 405 (용두동)     GS칼텍스
# 7   서울특별시    HD현대오일뱅크㈜직영 스피드주유소        서울 동대문구 천호대로 453 (장안동)  HD현대오일뱅크
# 8   서울특별시                 열린주유소         서울 동대문구 한천로 263 (휘경동)     S-OIL
# 9   서울특별시                 삼영주유소        서울 동대문구 답십리로 258 (장안동)     SK에너지
# 10  서울특별시                 경동주유소               서울 동대문구 이문로 191     S-OIL
# 11  서울특별시       삼미상사(주)장안킹셀프주유소        서울 동대문구  한천로 100 (장안동)     SK에너지
# 12  서울특별시                 홍능주유소         서울 동대문구 홍릉로 87 (청량리동)     S-OIL
# 13  서울특별시            한영주유소 (한화)          서울 동대문구 망우로 38 (휘경동)  HD현대오일뱅크
# 14  서울특별시      (주)안국에너지 삼원셀프주유소          서울 동대문구 망우로 90 (휘경동)     SK에너지
# 15  서울특별시               오동나무주유소        서울 동대문구  한천로 81 (답십리동)     S-OIL
#
#              전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0     02-487-2030    Y     -  1719  1549     -
# 1     02-442-5145    Y  1925  1725  1575     -
# 2     02-441-0536    N     -  1738  1587     -
# 3     02-441-3327    Y  1950  1758  1636  1599
# 4     02-474-7222    N  1965  1766  1648  1500
# 5    02-6956-6674    Y  1976  1776  1668  1590
# 6     02-484-1162    Y     -  1780  1650     -
# 7     02-484-6165    N  1943  1785  1665     -
# 8     02-479-3838    Y     -  1790  1690     -
# 9     02-442-7801    Y  1999  1799  1649  1600
# 10    02-484-9323    N     -  1895  1792     -
# 11    02-426-5372    Y  2149  1979  1804     -
# 12    02-470-5133    N     -  2018  1858  1800
# 0    02-2216-7155    Y  1890  1667  1507     -
# 1     02-969-1144    Y  1859  1667  1507     -
# 2     02-924-5189    N     -  1675  1515     -
# 3    02-2249-6682    Y     -  1677  1517     -
# 4    02-2242-0556    Y     -  1677  1517     -
# 5   070-8256-4617    Y  1900  1677  1517     -
# 6     02-966-5451    Y  1879  1699  1565     -
# 7    02-2216-5151    N  1899  1704  1579     -
# 8    02-2215-6543    N     -  1715  1589     -
# 9    02-2217-2018    N     -  1715  1587  1700
# 10  010-6775-6631    Y     -  1735  1595     -
# 11   02-2242-7115    Y     -  1737  1597     -
# 12    02-966-9190    N     -  1745  1597  1400
# 13   02-2214-9890    N     -  1747  1598  1490
# 14   02-2244-1972    Y     -  1748  1588  1460
# 15   02-2247-5132    N     -  1778  1628  1600

# %%
import pandas as pd
from glob import glob
from tqdm.notebook import tqdm
import os

# OS마다 차이가 있습니다. 파일 이름을 주의해서 불러옵니다.
# glob 함수를 이용해서 엑셀파일 목록을 가져옵니다.
stations_files = glob('./data/*.xls')


# tmp_raw = []
total = pd.DataFrame()
for file_name in tqdm(stations_files):
    temp = pd.read_excel(file_name, header=2)
    total = pd.concat([total, temp])
    # os.rename 함수를 이용하여 파일이름을 바꿉니다.

    # 리스트에 저장.
    
total = total.sort_values(by="지역")
total = total.reset_index(drop=True)
total.to_excel('./all_oilbank.xlsx', index=False)
# # 엑셀 파일을 하나로 합칩니다.
# station_raw = 

# # 주어진 이름을 가지는 excel 파일을 생성합니다.
# Out:
#   0%|          | 0/264 [00:00<?, ?it/s]

# %% [markdown]
# ### 이번엔 모든 시/도에 대해서 적용해 봅니다.

# %%
for do in tqdm(do_names):
    # 각 지역도 입력.

    
    # 도마다 구 명단 가져오기.
    
    
    
    for gu in tqdm(gu_names):
    
    
    
    # 도 단위별 엑셀파일 만들기.
