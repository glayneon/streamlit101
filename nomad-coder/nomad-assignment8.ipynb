# %%
from bs4 import BeautifulSoup
import requests
import sys

# %%
# variables
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
}

# for test
example_keywords = [
    'python',
    'typescript',
    'javascript',
]


class BerlinJobs:

    def __init__(self, headers=headers):
        self.pages = 0
        self.job_data = []
        self.berlin_jobs = {
            'it': 'https://berlinstartupjobs.com/engineering/',
            'specific': 'https://berlinstartupjobs.com/skill-areas/XXXXXX/',
        }

        self.headers = headers

    
    def scrap_jobs(self, keyword='it'):
        if keyword == 'it':
            url = self.berlin_jobs['it']
        else:
            url = self.berlin_jobs['specific'].replace('XXXXXX', keyword)

        print(f"Scrapping {url}...")
        response = requests.get(url, headers=self.headers)

        # conditional for either the site is alive.
        if response.status_code != 200:
            print(f"Something Wrong!! \nStatus Code : {response.status_code}")
            sys.exit(1)
        else:
            print(f"Scrapping is done...")

        # conditional for pages
        self.soup = BeautifulSoup(response.text, 'html.parser')
        self.pages = len(self.soup.find_all(class_='page-numbers'))
        if self.pages == 0:
            print("There's only One Page...")
            # minimum value for looping one time
            self.pages = 2
        
        for page in range(1, self.pages):
            if self.pages > 2:
                url_page = url + f"page/{str(page)}"
                print(f"Scrapping {url_page}...")
                response = requests.get(url_page, headers=self.headers)
                self.soup = BeautifulSoup(response.text, 'html.parser')

            jobs = self.soup.find_all('div', class_='bjs-jlid__wrapper')
            for job in jobs:
                link = job.find('h4', class_='bjs-jlid__h').find('a')['href']
                title = job.find('h4', class_='bjs-jlid__h').text
                company = job.find('a', class_='bjs-jlid__b').text
                desc = job.find('div', class_='bjs-jlid__description').text
    
                self.job_data.append([
                    title,
                    company,
                    link,
                    desc,
                ])


    def show_jobs(self):
        if self.job_data:
            for job_info in self.job_data:
                print(job_info)
        else:
            print("no data..")

# condition test for https://berlinstartupjobs.com/engineering/
# jobs = BerlinJobs()
# jobs.scrap_jobs()
# jobs.show_jobs()

# condition for keyword is python or else
jobs = BerlinJobs()
jobs.scrap_jobs(keyword='typescript')
jobs.show_jobs()
# Out:
# Scrapping https://berlinstartupjobs.com/skill-areas/typescript/...
# Scrapping is done...
# There's only One Page...
# ['(Senior) Developer Fullstack (Typescript / Javascript / Node.js)', 'DATATRONiQ', 'https://berlinstartupjobs.com/engineering/senior-developer-fullstack-typescript-javascript-node-js-m-f-d-datatroniq/', '\n\t\t\t🚀 DATATRONiQ stands out as a pioneering deep-tech 💪 startup for the industrial IoT in Germany. Our platform offers a one-stop solution for companies to monitor and optimize their assets and processes. Our device management and data acquisition technology generate high-quality data for our AI models deployed on edge. We believe in an open and...\t\t']
# ...

# %%
jobs = BerlinJobs()
jobs.scrap_jobs()
# Out:
# Scrapping https://berlinstartupjobs.com/engineering/...
# Scrapping is done on https://berlinstartupjobs.com/engineering/.

# %%
aaa = jobs.soup.find_all('div', class_='bjs-jlid__wrapper')

# %%
link = aaa[0].find('h4', class_='bjs-jlid__h').find('a')['href']
link
# Out:
# 'https://berlinstartupjobs.com/engineering/senior-software-engineer-node-js-m-f-d-solarize/'

# %%
title = aaa[0].find('h4', class_='bjs-jlid__h').text
title
# Out:
# 'Senior Software Engineer – Node.js (m/f/d)'

# %%
company = aaa[0].find('a', class_='bjs-jlid__b').text
company
# Out:
# 'Solarize'

# %%
desc = aaa[0].find('div', class_='bjs-jlid__description').text
desc
# Out:
# '\n\t\t\tSolarize is an early stage startup driven by a team with extensive experience in B2B Software as a Service. Our mission is to streamline the billing of electricity deliveries in commercial tenant power and microgrid projects through automation. We are committed to advancing the energy transition by working towards a future where every building can...\t\t'

# %%
pages = jobs.soup.find_all(class_='page-numbers')
# Out:
# 3

# %%
for i in range(0,1):
    print(type(i))
# Out:
# <class 'int'>

# %%
a = "PAGE/XXX/"
a.replace('XXX', '2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 2
#       1 a = "PAGE/XXX/"
# ----> 2 a.replace()
#
# TypeError: replace expected at least 2 arguments, got 0

# %%
response = requests.get('https://berlinstartupjobs.com/skill-areas/python/', headers=headers)
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<link rel="profile" href="https://gmpg.org/xfn/11">\n\t<link rel="pingback" href="https://berlinstartupjobs.com/xmlrpc.php">\n\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n\n\t<!-- This site is optimized with the Yoast SEO plugin v19.14 - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Python Jobs in Berlin | Berlin Startup Jobs</title>\n\t<link rel="canonical" href="https://berlinstartupjobs.com/skill-areas/python/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Python Jobs in Berlin | Berlin Startup Jobs" />\n\t<meta property="og:url" content="https://berlinstartupjobs.com/skill-areas/python/" />\n\t<meta property="og:site_name" content="Berlin Startup Jobs" />\n\t<meta 
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
pages = len(soup.find_all(class_='page-numbers'))
pages
# Out:
# 0

# %%
jobs = soup.find_all('div', class_='bjs-jlid__wrapper')

# %%
jobs[0]
# Out:
# <div class="bjs-jlid__wrapper">
# <div class="bjs-jlid__header">
# <a class="bjs-jlis__logo" href="https://berlinstartupjobs.com/companies/datatroniq/">
# <img alt="DATATRONiQ logo" src="https://berlinstartupjobs.com/wp-content/uploads/Logo_Datatroniq_Square_Firmenbeschreibung-1-80x80.png">
# </img></a>
# <div class="bjs-jlid__meta">
# <h4 class="bjs-jlid__h"><a href="https://berlinstartupjobs.com/engineering/senior-developer-fullstack-typescript-javascript-node-js-m-f-d-datatroniq/">(Senior) Developer Fullstack (Typescript / Javascript / Node.js)</a></h4>
# <a class="bjs-jlid__b" href="https://berlinstartupjobs.com/companies/datatroniq/">DATATRONiQ</a>
# </div><!-- end .bjs-jlis__meta -->
# <p class="bjs-jlid__featured">
# <span class="icon-star"></span>
# 					featured				</p>
# </div>
# <div class="links-box">
# <a class="bjs-bl bjs-bl-porcelain" href="https://berlinstartupjobs.com/skill-areas/backend/">
# 	Backend</a>
# ...

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://berlinstartupjobs.com/xmlrpc.php" rel="pingback"/>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <!-- This site is optimized with the Yoast SEO plugin v19.14 - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Python Jobs in Berlin | Berlin Startup Jobs</title>
# <link href="https://berlinstartupjobs.com/skill-areas/python/" rel="canonical">
# <meta content="en_US" property="og:locale">
# <meta content="article" property="og:type"/>
# <meta content="Python Jobs in Berlin | Berlin Startup Jobs" property="og:title"/>
# <meta content="https://berlinstartupjobs.com/skill-areas/python/" property="og:url"/>
# <meta content="Berlin Startup Jobs" property="og:site_name"/>
# ...

# %%
from bs4 import BeautifulSoup
import requests

# variables
headers = {
    'user-agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36',
}

# for test
example_keywords = [
    'python',
    'typescript',
    'javascript',
]


class BerlinJobs:

    def __init__(self, headers=headers):
        self.pages = 0
        self.job_data = []
        self.berlin_jobs = {
            'it': 'https://berlinstartupjobs.com/engineering/',
            'specific': 'https://berlinstartupjobs.com/skill-areas/XXXXXX/',
        }

        self.headers = headers

    def scrap_jobs(self, keyword='it'):
        if keyword == 'it':
            url = self.berlin_jobs['it']
        else:
            url = self.berlin_jobs['specific'].replace('XXXXXX', keyword)

        print(f"Scrapping {url}...")
        response = requests.get(url, headers=self.headers)

        # conditional for either the site is alive.
        if response.status_code != 200:
            print(f"Something Wrong!! \nStatus Code : {response.status_code}")
            sys.exit(1)
        else:
            print(f"Scrapping is done...")

        # conditional for pages
        self.soup = BeautifulSoup(response.text, 'html.parser')
        pages = len(self.soup.find_all(class_='page-numbers'))
        current = 1

        while True:
            # parsing the current page
            jobs = self.soup.find_all('div', class_='bjs-jlid__wrapper')
            for job in jobs:
                link = job.find('h4', class_='bjs-jlid__h').find('a')['href']
                title = job.find('h4', class_='bjs-jlid__h').text
                company = job.find('a', class_='bjs-jlid__b').text
                desc = job.find('div', class_='bjs-jlid__description').text

                self.job_data.append([
                    title,
                    company,
                    link,
                    desc,
                ])

            # conditional for pagenation
            current += 1
            if pages != 0 and current != pages:
                url_page = url + f"page/{str(current)}"
                print(f"Scrapping {url_page}...")
                response = requests.get(url_page, headers=self.headers)
                self.soup = BeautifulSoup(response.text, 'html.parser')
            else:
                break

    def show_jobs(self):
        if self.job_data:
            for job_info in self.job_data:
                print(job_info)
        else:
            print("no data..")


## the case for https://berlinstartupjobs.com/engineering/ and pagenation processing
jobs = BerlinJobs()
jobs.scrap_jobs()
jobs.show_jobs()

## the case for keywords
for keyword in example_keywords:
    jobs = BerlinJobs()
    jobs.scrap_jobs(keyword=keyword)
    jobs.show_jobs()
# Out:
# Scrapping https://berlinstartupjobs.com/engineering/...
# Scrapping is done...
# Scrapping https://berlinstartupjobs.com/engineering/page/2...
# ['Senior Software Engineer – Node.js (m/f/d)', 'Solarize', 'https://berlinstartupjobs.com/engineering/senior-software-engineer-node-js-m-f-d-solarize/', '\n\t\t\tSolarize is an early stage startup driven by a team with extensive experience in B2B Software as a Service. Our mission is to streamline the billing of electricity deliveries in commercial tenant power and microgrid projects through automation. We are committed to advancing the energy transition by working towards a future where every building can...\t\t']
# ...
